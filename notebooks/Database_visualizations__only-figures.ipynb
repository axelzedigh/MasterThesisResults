# %% [markdown]
# # Database visualization

# %%
import pandas as pd

from plots.plot_functions import plot_best_additive_noise_methods, plot_all_of_an_additive_noise, plot_all_of_denoising, plot_epoch_comparison, plot_additive_noise_comparison_all

# %% [markdown]
# ## Compare Additive noise methods - Trace process 3

# %% [markdown]
# Trace process 3: Normalization of traces to range (0, 1). Max and min values determined by values in the whole trace range (400 data points).

# %%
wang, zedigh = plot_best_additive_noise_methods()

# %% [markdown]
# ## Gaussians - epoch 65, distance 15

# %%
wang, zedigh = plot_all_of_an_additive_noise(additive_noise_method="Gaussian", distance=15)

# %% [markdown]
# ## Collected noise

# %%
wang, zedigh = plot_all_of_an_additive_noise(additive_noise_method="Collected", distance=15)

# %% [markdown]
# ## Rayleigh Noise

# %%
wang, zedigh = plot_all_of_an_additive_noise(additive_noise_method="Rayleigh", distance=15)

# %% [markdown]
# ## Denoising - Moving Average filter

# %%
wang, zedigh = plot_all_of_denoising()

# %% [markdown]
# ## Epoch analysis

# %% [markdown]
# ### Epoch - Collected 50

# %%
wang = plot_epoch_comparison(test_dataset="Wang_2021", device=6, distance=15, additive_noise_method="Collected", additive_noise_method_parameter_1_value=50)

# %% [markdown]
# ### Epoch - Rayleigh 0.0138

# %%
wang = plot_epoch_comparison(test_dataset="Wang_2021", device=6, distance=15, additive_noise_method="Rayleigh", additive_noise_method_parameter_1_value=0.0138)

# %% [markdown]
# ## Epoch - Gaussian 0.04

# %%
wang = plot_epoch_comparison(test_dataset="Wang_2021", device=6, distance=15, additive_noise_method="Gaussian", additive_noise_method_parameter_1_value=0.04)

# %% [markdown]
# ## Comparision between methods, distance and device non-specific

# %%
data = plot_additive_noise_comparison_all()
